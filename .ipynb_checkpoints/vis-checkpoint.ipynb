# %%
# %matplotlib inline
from dataset import DataSet
import matplotlib.pyplot as plt
from glob import glob
images = sorted(glob("/datasets/UCSD_Anomaly_Dataset_v1p2/UCSDped1/Test/Test003/*.tif"))

ds = DataSet(images, [0] * len(images), mask_background=True, is_video=False, visualize=True)
img, label = ds.__getitem__(150)

display(img.shape)
img = img.numpy().transpose(0, 1, 3, 4, 2)
display(img.shape)

plt.imshow(img[0, 0])
plt.show()

plt.imshow(img[1, 0])
plt.show()
# Out:
# torch.Size([2, 1, 3, 158, 238])
# (2, 1, 158, 238, 3)
